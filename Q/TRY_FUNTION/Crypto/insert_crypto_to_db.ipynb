# %%
import pandas as pd
import html5lib
import sqlite3

# %%
def insert_share(data):

    conn = sqlite3.connect(r'C:\Users\JourneyQ\OneDrive - kmutnb.ac.th\Desktop\Quick_file\year_2-S_2\Project_sofedev_2\Manage_Share\Database_convert\share_V2.sqlite')
    cur = conn.cursor()

    check_query = f"""SELECT count(*) FROM Information WHERE Symbol = "{data['Symbol']}" and Sname = "{data['Name']}";"""
    cur.execute(check_query)
    result = cur.fetchone()

    if result[0] == 0:
        # Data does not exist, insert it
        insert_data = f""" INSERT INTO Information("Symbol","Sname") VALUES("{data['Symbol']}","{data['Name']}")"""
        cur.execute(insert_data)
        conn.commit()
        conn.close()
        return "1",data['Symbol']
        
    return "0",data['Symbol']

# %%
df = pd.read_csv('Crypto300.csv')

# %%
df
# Out:
#     Symbol         Name
# 0      BTC      Bitcoin
# 1      ETH     Ethereum
# 2     USDT       Tether
# 3      BNB          BNB
# 4     USDC     USD Coin
# ..     ...          ...
# 295    SRM        Serum
# 296   CEEK      CEEK VR
# 297    WIN     WINkLink
# 298   USDX  USDX [Kava]
# 299    REN          Ren
#
# [300 rows x 2 columns]

# %%
market = {'SET':1,'NASDAQ':2,'CRYPTO':3}
error = []
for i in range(len(df['Symbol'])):

    print(df.iloc[i]['Symbol'])
    s,share = insert_share(df.iloc[i])

    if s == '0':
        error.append(share)
# Out:
# BTC
# ETH
# USDT
# BNB
# USDC
# XRP
# ADA
# BUSD
# MATIC
# DOGE
# SOL
# DOT
# SHIB
# LTC
# TRX
# AVAX
# UNI
# DAI
# WBTC
# ATOM
# LINK
# FIL
# LEO
# ETC
# OKB
# XMR
# TON
# BCH
# LDO
# XLM
# HBAR
# APT
# ICP
# NEAR
# VET
# APE
# CRO
# ALGO
# QNT
# GRT
# FTM
# EOS
# FLOW
# MANA
# EGLD
# AAVE
# BIT
# AXS
# THETA
# SAND
# XTZ
# RPL
# LUNC
# TUSD
# CHZ
# KLAY
# CRV
# KCS
# MINA
# USDP
# IMX
# HT
# BSV
# FXS
# CAKE
# DASH
# ZEC
# NEO
# MKR
# USDD
# MIOTA
# XEC
# BTT
# GMX
# SNX
# OP
# TWT
# GUSD
# LRC
# RUNE
# STX
# OSMO
# ZIL
# BLUR
# AGIX
# BNX
# GT
# ENJ
# PAXG
# CVX
# DYDX
# 1INCH
# RNDR
# BAT
# AR
# ETHW
# ASTR
# WOO
# ROSE
# COMP
# CSPR
# FEI
# NEXO
# MAGIC
# LUNA
# HNT
# CELO
# KSM
# KAVA
# RVN
# HOT
# BONE
# XEM
# XDC
# DCR
# T
# TFUEL
# FET
# CFX
# BAL
# ONE
# SSV
# JASMY
# QTUM
# AUDIO
# GALA
# ENS
# SUSHI
# ANKR
# INJ
# XCN
# BTG
# GLMR
# IOTX
# OCEAN
# WAVES
# XCH
# MASK
# GNO
# GMT
# KDA
# USTC
# YFI
# JST
# BAND
# GLM
# SKL
# ELON
# SC
# LPT
# OMG
# FLUX
# RSR
# ICX
# BICO
# XYM
# CHSB
# ONT
# IOST
# ZRX
# SYN
# HIVE
# SFP
# DAO
# AMP
# SXP
# BORA
# STORJ
# STG
# ILV
# POLY
# WAXP
# CKB
# ZEN
# METIS
# KEEP
# DGB
# EVER
# RLC
# TKO
# LSK
# CELR
# HFT
# SYS
# PEOPLE
# UMA
# KNC
# HOOK
# NFT
# TRAC
# MC
# VGX
# MOB
# PLA
# EWT
# SLP
# ELF
# BTRST
# SCRT
# CHR
# HEX
# WTRX
# stETH
# BTCB
# WBNB
# TMG
# FRAX
# HBTC
# BTTOLD
# TNC
# FTT
# BGB
# XRD
# WEMIX
# FLOKI
# XAUT
# BabyDoge
# NXM
# LN
# DFI
# USDJ
# MV
# LUSD
# ALI
# ANY
# EDGT
# BRISE
# COCOS
# TEL
# LYXe
# WEVER
# BDX
# RON
# TSUKA
# VVS
# GTC
# MED
# API3
# EURS
# MX
# GAL
# ACH
# PUNDIX
# KAS
# NMR
# XTN
# XNO
# ANT
# COTI
# CEL
# RBN
# CTC
# POLYX
# AXL
# SNT
# TRIBE
# CVC
# CFG
# DENT
# LOCUS
# REP
# REQ
# HIGH
# LOOKS
# ONG
# CTSI
# PYR
# NYM
# NU
# DEXE
# MVL
# SAITAMA
# VTHO
# ORBS
# RAD
# vUSDC
# ARDR
# SPELL
# MBOX
# VRA
# ALPHA
# HUM
# STEEM
# ERG
# MNW
# DUSK
# POWR
# DKA
# AVINOC
# PHA
# LCX
# VOLT
# POND
# PROM
# IQ
# SRM
# CEEK
# WIN
# USDX
# REN

# %%
# Out:
# []
