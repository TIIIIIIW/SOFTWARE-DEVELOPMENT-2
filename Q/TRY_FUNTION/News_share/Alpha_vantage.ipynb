# %%
pip install alpha-vantage
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from alpha_vantage.timeseries import TimeSeries
API_Key = 'S1W2QM4NOB9CC8K'

ts = TimeSeries(key = API_Key,output_format='pandas')

data = ts.get_intraday('AAPL',interval= '5min')

# %%
data[0]
# Out:
#                      1. open   2. high    3. low  4. close  5. volume
# date
# 2023-02-10 20:00:00  151.200  151.2600  151.2000  151.2600    10821.0
# 2023-02-10 19:55:00  151.140  151.2000  151.1400  151.2000     2397.0
# 2023-02-10 19:50:00  151.070  151.0900  151.0700  151.0900     1147.0
# 2023-02-10 19:45:00  151.040  151.0500  151.0400  151.0500     1558.0
# 2023-02-10 19:40:00  151.010  151.0400  151.0100  151.0100      631.0
# ...                      ...       ...       ...       ...        ...
# 2023-02-10 11:50:00  150.110  150.1600  149.7800  149.9600   517929.0
# 2023-02-10 11:45:00  150.210  150.3000  150.0800  150.1100   291976.0
# 2023-02-10 11:40:00  150.110  150.2800  150.1000  150.2200   351659.0
# 2023-02-10 11:35:00  150.300  150.3499  150.0150  150.1200   406347.0
# 2023-02-10 11:30:00  150.685  150.6950  150.2657  150.2854   421549.0
#
# [100 rows x 5 columns]

# %%
import os
import requests
import pandas as pd
function = "NEWS_SENTIMENT"

tickers = 'IBM'
topics = "technology"

# https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers={tickers}&apikey={API_Key}
url = f'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers={tickers}&apikey={API_Key}'

r = requests.get(url)
data = r.json()
news = pd.DataFrame(data['feed']).head()

# %%
news
# Out:
#                                                title  ...                                   ticker_sentiment
# 0        Cisco Q2 Preview: Another EPS Beat Inbound?  ...  [{'ticker': 'IBM', 'relevance_score': '0.27586...
# 1  Parking Management Market Report will Worth US...  ...  [{'ticker': 'MMM', 'relevance_score': '0.02792...
# 2  Intelligent Traffic Management System Market R...  ...  [{'ticker': 'TMOAF', 'relevance_score': '0.028...
# 3  IBM LAWSUIT ALERT: Levi & Korsinsky Notifies I...  ...  [{'ticker': 'IBM', 'relevance_score': '0.62847...
# 4  Private cloud services market size to grow at ...  ...  [{'ticker': 'BABA', 'relevance_score': '0.0845...
#
# [5 rows x 13 columns]

# %%
def save_csv(df,name):

    name += ".xlsx"
    df.to_excel(name,index=False)
    
    return "succes"

# %%
save_csv(news,'News_from_alpha_vantage')
# Out:
# 'succes'
